# %% [markdown]
# # 1 File Load

# %%
import file_load_v4_autoXML_chanmap_EEG

# %%
#import pickle_to_MNE_to_BPF_v2_autoSfreq_ERG_EEG_v3_nanSafe

# this version features multiple NaN handling options 

# Drop epochs with NaNs/Infs (recommended)

# Interpolate NaNs/Infs (linear)

# Fill NaNs with constant

# Error if NaNs/Infs present

# %%
#import pickle_to_MNE_to_BPF_v4_nanPreserve_likeEyeavg

# %%
# import pickle_to_MNE_to_BPF_v5_nanPreserve_UIclean

# %% [markdown]
# # 2 NaN sensitive BPF that handles ERG/EEG

# %%
import pickle_to_MNE_to_BPF_v6_nanPreserve_0_100HzDefault

# %% [markdown]
# # 3 PSD clean NaN sensitive that handles ERG/EEG

# %%
# import psd_clean_v5_import_psdCompute_varSfreqSafe_nanSafe

# %%
# import psd_clean_v6_import_psdCompute_varSfreqSafe_nanDropFixed

# %%
# import psd_clean_v7_import_psdCompute_varSfreqSafe_nanDropFixed_0_100HzPSD

# %%
import psd_clean_v8_import_psdCompute_varSfreqSafe_nanWelchLongestSeg_0_100Hz_fix1

# %% [markdown]
# # 4 Channel Mean Compute that is NaN sensitive and handles ERG/EEG

# %%
# import psd_channel_means_v3d_NaN_eyeEEGExcel_EEGpanel_Excel4col as psd_means
# psd_means.launch_psd_channel_means_nan_gui()

# %%
#import psd_channel_means_v3c_NaN_eyeEEGExcel_EEGpanel as psd_means
# psd_means.launch_psd_channel_means_nan_gui()

# %%
import psd_channel_means_v3b_NaN_eyeEEGExcel_3chHeuristic as psd_means
psd_means.launch_psd_channel_means_nan_gui()

# To individually display the plots select them in 2) channels before hitting "plot channels means"  
# To visualze the all three channels and export them correctly, select all three channels in "2) Channel selection" 
# and then click "Plot final Eye1/Eye2" green button

# %%
#import psd_channel_means_v2b_NaN_eyeEEGExcel as psd_means
# psd_means.launch_psd_channel_means_nan_gui()

# %% [markdown]
# # 5 Fitting data in log_log

# %%
#import sys
#sys.path.append(r"C:\Users\GhezziLab\rsERG_project_v3\rsERG_MEA_v2_venv\Mouse_rsERG\Artifact_Reject")

#import psd_channel_means_v1b_NaN
#psd_channel_means_v1b_NaN.launch_psd_channel_means_nan_gui()

# %%
import excel_to_1darray_to_FOOOF_v1A11_agg_log_log

# %% [markdown]
# # 6 Aperiodic Fitting

# %%
#import psd_pkl_epochs_to_FOOOF_aperiodic_v1 as fooof_ap
#fooof_ap.build_psd_pkl_fooof_aperiodic_gui()

# %%
#import psd_pkl_epochs_to_FOOOF_aperiodic_v2_autoInspect as fooof_ap
#fooof_ap.build_psd_pkl_fooof_aperiodic_gui()

# %%
import psd_pkl_epochs_to_FOOOF_aperiodic_v3_titleParams_autoInspect as fooof_ap
fooof_ap.build_psd_pkl_fooof_aperiodic_gui()

# %%
import psd_pkl_epochs_to_FOOOF_aperiodic_v4_binnedSeries_peaksExcel as fooof_ap
fooof_ap.build_psd_pkl_fooof_aperiodic_gui()
