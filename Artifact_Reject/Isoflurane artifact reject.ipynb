# %%
import neuroviz_deps as nv
nv.show_status()      # see what imported vs. what's missing
nv.versions()         # dict of key package versions
# nv.set_matplotlib_qt()  # optional: switch backend to Qt5Agg

# %%
import file_view_v3

# %%
import pickle_to_MNE_artifact_GUI_v1_2000hz

# %%
import pickle_to_MNE_artifact_GUI_v1_2000hz_v2

# %%
from artifact_excision_resegment_5s_v1 import clean_and_export

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

epochs_clean = clean_and_export(
    input_pkl_path=input_pkl,
    output_fif_path=r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\Filtered100_artifact_drop\1_C57_220_Isoflurane0p5per_up_cleaned.fif",
    sfreq=2000.0,        # or your actual sampling rate
    epoch_len_s=5.0,     # 5 s epochs
    amp_z_hard=5.0,      # (i) amplitude
    deriv_z_hard=5.0,    # (ii) derivative
    drift_z_thresh=5.0,  # (iii) drift power
    intercept_z_thresh=5.0,  # (iv) 1/f intercept
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
    l_freq=0.0,
    h_freq=100.0,
)

# %%
from artifact_excision_nanmark_5s_v1 import nanmark_and_export

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\4_C57_220_Isoflurane2per_up_epoched.pkl"

epochs_nan = nanmark_and_export(
    input_pkl_path=input_pkl,
    output_fif_path=r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\Filtered100_nan5s\4_C57_220_Isoflurane2per_nan5s.fif",
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=7.0,
    deriv_z_hard=7.0,
    drift_z_thresh=7.0,
    intercept_z_thresh=7.0,
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
    l_freq=0.5,      # band-pass before NaN marking
    h_freq=100.0,
)

# %%
from artifact_excision_viewer_gui_v1 import launch_artifact_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,      # 5 s windows for drift / 1/f, matched to your epochs
    amp_z_hard=4.0,       # (i) amplitude
    deriv_z_hard=3.0,     # (ii) derivative
    drift_z_thresh=3.0,   # (iii) drift power
    intercept_z_thresh=3.0,  # (iv) 1/f intercept
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
)

# %%
from artifact_excision_viewer_gui_v2 import launch_artifact_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=6.0,
    deriv_z_hard=6.0,
    drift_z_thresh=6.0,
    intercept_z_thresh=7.0,
    min_dur_ms_amp=5.0,
    min_dur_ms_deriv=5.0,
)

# %%
import importlib

import artifact_excision_eyeavg_viewer_v1
importlib.reload(artifact_excision_eyeavg_viewer_v1)

from artifact_excision_eyeavg_viewer_v1 import launch_artifact_viewer

# %%
input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=6.0,
    deriv_z_hard=6.0,
    drift_z_thresh=6.0,
    intercept_z_thresh=7.0,
    min_dur_ms_amp=5.0,
    min_dur_ms_deriv=5.0,
    average_eye_groups=True,      # turn on Eye1/Eye2 averaging
    drop_indices_eye1=[0, 1, 2],  # drop channels 0,1,2 before averaging Eye1
    # drop_indices_eye2=[...]     # optional: drop some from Eye2
)
# Out:
# Eye averaging configuration:
#   Eye1 indices used: [3, 4, 5, 6, 7]
#   Eye2 indices used: [8, 9, 10, 11, 12, 13, 14, 15]
# ...

# %%
from artifact_excision_viewer_gui_v3 import launch_artifact_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=5.0,
    deriv_z_hard=5.0,
    drift_z_thresh=5.0,
    intercept_z_thresh=5.0,
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
)

# %%
from artifact_excision_viewer_gui_v4 import launch_artifact_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=5.0,
    deriv_z_hard=5.0,
    drift_z_thresh=5.0,
    intercept_z_thresh=5.0,
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
)

# %%
import psd_compute
