# %%
from artifact_excision_viewer_gui_v2 import launch_artifact_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=6.0,
    deriv_z_hard=6.0,
    drift_z_thresh=6.0,
    intercept_z_thresh=7.0,
    min_dur_ms_amp=5.0,
    min_dur_ms_deriv=5.0,
)

# %%
from artifact_excision_nanmark_5s_v1 import nanmark_and_export

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\4_C57_220_Isoflurane2per_up_epoched.pkl"

epochs_nan = nanmark_and_export(
    input_pkl_path=input_pkl,
    output_fif_path=r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\Filtered100_nan5s\4_C57_220_Isoflurane2per_nan5s.fif",
    sfreq=2000.0,
    epoch_len_s=5.0,
    amp_z_hard=7.0,
    deriv_z_hard=7.0,
    drift_z_thresh=7.0,
    intercept_z_thresh=7.0,
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
    l_freq=0.5,      # band-pass before NaN marking
    h_freq=100.0,
)

# %%
from nanmark_cleaned_viewer_gui_v1 import launch_nan_cleaned_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_nan_cleaned_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,          # for spectral criteria
    amp_z_hard=4.0,
    deriv_z_hard=3.0,
    drift_z_thresh=3.0,
    intercept_z_thresh=3.0,
    min_dur_ms_amp=5.0,
    min_dur_ms_deriv=5.0,
    l_freq=0.5,               # same filter you plan to use
    h_freq=100.0,
)
# Out:
# [launch_nan_cleaned_viewer] Loading pickle: D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl
#   Continuous data shape: (n_channels=16, n_times=2400000)
#   Total duration: 1200.00 s
#   Epoch length (for spectral criteria): 10000 samples (5.00 s)
# Artifact counts per criterion (samples, not mutually exclusive):
#   amp      :   95398 samples (~  47.70 s)
#   deriv    :     900 samples (~   0.45 s)
#   drift    :   50000 samples (~  25.00 s)
#   intercept:   30000 samples (~  15.00 s)
# Combined (union): 134675 samples (~67.34 s)
# Remaining clean (non-artifact):  2265325 samples (~1132.66 s)
# Fraction marked as artifact: 5.61%
# Applying band-pass filter before NaN marking: 0.5-100.0 Hz (fir_design=firwin, filter_length=auto)
# Setting up band-pass filter from 0.5 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 13201 samples (6.601 s)
#
# Launching interactive viewer for NaN-marked cleaned time series...
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.5s finished
# VBox(children=(HTML(value='<h3>NaN-marked Cleaned Time Series Viewer</h3>'), HTML(value='<b>Total duration:</b…

# %%
from artifact_excision_viewer_gui_v1 import launch_artifact_viewer

input_pkl = r"D:\Open Ephys\Isoflurane\C57 220\20251114\Analysis\MNE Array\1_C57_220_Isoflurane0p5per_up_epoched.pkl"

launch_artifact_viewer(
    input_pkl_path=input_pkl,
    sfreq=2000.0,
    epoch_len_s=5.0,      # 5 s windows for drift / 1/f, matched to your epochs
    amp_z_hard=4.0,       # (i) amplitude
    deriv_z_hard=3.0,     # (ii) derivative
    drift_z_thresh=3.0,   # (iii) drift power
    intercept_z_thresh=3.0,  # (iv) 1/f intercept
    min_dur_ms_amp=10.0,
    min_dur_ms_deriv=8.0,
)
